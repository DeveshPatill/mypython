# %%
# %pip install yfinance pandas matplotlib
# %import mplfinance as mpf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (0.2.54)
# Requirement already satisfied: pandas in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (3.10.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: requests>=2.31 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# UsageError: Line magic function `%import` not found.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
#element banana hai 
ticker = "AAPL"
start_date = "2023-01-01"
end_date = "2025-03-01"
stock_data = yf.download(ticker,start_date, end=end_date)
stock_data.to_csv("AAPL_stock_data.csv")
print(stock_data.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.632523  129.395510  122.742865  128.782641  112117500
# 2023-01-04  124.907700  127.181268  123.642412  125.431607   89113600
# 2023-01-05  123.583107  126.301500  123.326101  125.668857   80962700
# 2023-01-06  128.130234  128.792531  123.454601  124.561732   87754700
# 2023-01-09  128.654144  131.876686  128.397138  128.970474   70790800

# %%
print("Data set shape",stock_data.shape)
# Out:
# Data set shape (541, 5)

# %%
print(stock_data.describe())
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   541.000000  541.000000  541.000000  541.000000  5.410000e+02
# mean    192.309393  193.883160  190.454177  192.036779  5.778716e+07
# std      29.885142   30.119642   29.551134   29.886695  2.473694e+07
# min     123.583107  126.301500  122.742865  124.561732  2.323470e+07
# 25%     171.808746  172.846853  169.992825  171.364025  4.468600e+07
# 50%     186.503082  187.783307  185.428686  186.728921  5.245640e+07
# 75%     222.230896  224.745375  219.890965  222.121137  6.475140e+07
# max     258.735504  259.814335  257.347047  257.906429  3.186799e+08

# %%
plt.Figure(figsize=(50,20))
plt.plot(stock_data.index,stock_data['Close'],label="Closing Price",color="red")
plt.title("AAPL Closing Price",fontsize=20)
plt.xlabel('Date',fontsize=12)
plt.ylabel('Price (USD)',fontsize=12)
plt.grid(True)
plt.xticks(rotation=50)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# %pip install mplfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mplfinance in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from mplfinance) (3.10.1)
# Requirement already satisfied: pandas in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from mplfinance) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from pandas->mplfinance) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from pandas->mplfinance) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\devesh patil\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mplfinance as mpf

stock_data.columns = stock_data.columns.get_level_values(0)

mpf.plot(stock_data,type="candle",style='charles',title="AAPLE Candlestick chart",
         xlabel ="price (usd)",volume=True,
         ylabel_lower="Volume",figsize=(12,9))

# %%
fig,(ax1,ax2)=plt.subplots(2,1,figsize=(12,9),sharex=True,gridspec_kw={'height_ratios':[3,1]})
ax1.plot(stock_data.index, stock_data['Close'],label='Closing Price',color='blue')
ax1.set_title('AAPLE Closing Price',fontsize=16)
ax1.set_ylabel('price (USD)',fontsize=12)
ax1.grid(True)
ax1.legend()

ax2.bar(stock_data.index,stock_data['Volume'],color="green",alpha=0.6)
ax2.set_xlabel('Date',fontsize=12)
ax2.set_ylabel('volume(Share)',fontsize=12)
ax2.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
